# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
football_data = pd.read_excel('Games Completed.xlsx')

# %%
football_data.head()
# Out:
#   Date (timeline)      Home Team Away Team  Home Score  Away Score  \
# 0      1930-07-13         France    Mexico           4           1
# 1      1930-07-13  United States   Belgium           3           0
# 2      1930-07-14        Romania      Peru           3           1
# 3      1930-07-14     Yugoslavia    Brazil           2           1
# 4      1930-07-15      Argentina    France           1           0
#
#        Tournament Attendance                 Stadium        City  Country  \
# 0  FIFA World Cup       4444         Estadio Pocitos  Montevideo  Uruguay
# 1  FIFA World Cup      18346  Estadio Parque Central  Montevideo  Uruguay
# 2  FIFA World Cup       2549         Estadio Pocitos  Montevideo  Uruguay
# 3  FIFA World Cup      24059  Estadio Parque Central  Montevideo  Uruguay
# 4  FIFA World Cup      23409  Estadio Parque Central  Montevideo  Uruguay
#
#   AET Y-N PEN Y-N Pen (x*x)                       Notes
# 0      NO      NO        NO  First FIFA World Cup Match
# ...

# %%
lst = [] 
for i in range(len(football_data)) : 
    if football_data['Home Score'][i] > football_data['Away Score'][i] :  
        data = football_data['Home Team'][i]
        new_lst = lst.append(data)
#         print(data)
#         print(lst)

    elif football_data['Home Score'][i] < football_data['Away Score'][i] :
        data = football_data['Away Team'][i]
        new_lst = lst.append(data)
#         print(type(data))

    else : 
        data = "EquaL"
        new_lst = lst.append(data)
#         print(len(data))


lst
# Out:
# ['France',
#  'United States',
#  'Romania',
#  'Yugoslavia',
#  'Argentina',
#  'Chile',
#  'United States',
#  'Yugoslavia',
#  'Uruguay',
#  'Argentina',
#  'Chile',
#  'Brazil',
#  'Paraguay',
#  'Uruguay',
#  'Argentina',
#  'Argentina',
#  'Uruguay',
#  'Uruguay',
#  'Sweden',
#  'Sweden',
#  'EquaL',
#  'Czechoslovakia',
#  'EquaL',
#  'Cuba',
#  'EquaL',
#  'Cuba',
#  'EquaL',
#  'Mexico',
#  'Germany',
#  'Mexico',
#  'Spain',
#  'Egypt',
#  'Mexico',
#  'Spain',
#  'Hungary',
#  'Italy',
#  'Egypt',
#  'Netherlands',
#  'Czechoslovakia',
#  'France',
#  'Austria',
#  'Netherlands',
#  'Hungary',
#  'Romania',
#  'United States',
#  'Austria',
#  'Czechoslovakia',
#  'Germany',
#  'Hungary',
#  'Italy',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Austria',
#  'Czechoslovakia',
#  'Germany',
#  'EquaL',
#  'Italy',
#  'Czechoslovakia',
#  'Italy',
#  'Germany',
#  'Italy',
#  'Sweden',
#  'Sweden',
#  'Germany',
#  'Latvia',
#  'Estonia',
#  'Germany',
#  'Latvia',
# ...

# %%
football_data['winner'] = lst

# %%
football_data
# Out:
#      Date (timeline)            Home Team    Away Team  Home Score  \
# 0         1930-07-13               France       Mexico           4
# 1         1930-07-13        United States      Belgium           3
# 2         1930-07-14              Romania         Peru           3
# 3         1930-07-14           Yugoslavia       Brazil           2
# 4         1930-07-15            Argentina       France           1
# ...              ...                  ...          ...         ...
# 8060      2021-10-12              Bahrain  New Zealand           0
# 8061      2021-10-12               Gambia  South Sudan           2
# 8062      2021-10-12  Republic of Ireland        Qatar           4
# 8063      2021-10-12               Jordan   Uzbekistan           3
# 8064      2021-10-27              Ecuador       Mexico           3
#
#       Away Score           Tournament Attendance                      Stadium  \
# 0              1       FIFA World Cup       4444              Estadio Pocitos
# ...

# %%
football_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8065 entries, 0 to 8064
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date (timeline)  8065 non-null   datetime64[ns]
#  1   Home Team        8065 non-null   object
#  2   Away Team        8065 non-null   object
#  3   Home Score       8065 non-null   int64
#  4   Away Score       8065 non-null   int64
#  5   Tournament       8065 non-null   object
#  6   Attendance       7291 non-null   object
#  7   Stadium          7586 non-null   object
#  8   City             8031 non-null   object
#  9   Country          8031 non-null   object
#  10  AET Y-N          8065 non-null   object
#  11  PEN Y-N          8065 non-null   object
#  12  Pen (x*x)        8065 non-null   object
#  13  Notes            74 non-null     object
#  14  winner           8065 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(12)
# memory usage: 945.2+ KB

# %%
football_data.describe().T
# Out:
#              count      mean       std  min  25%  50%  75%   max
# Home Score  8065.0  1.785493  1.815761  0.0  1.0  1.0  3.0  31.0
# Away Score  8065.0  1.113081  1.409157  0.0  0.0  1.0  2.0  22.0

# %%
football_data.describe(include = 'O').T
# Out:
#            count unique                        top  freq
# Home Team   8065    240                     Brazil   132
# Away Team   8065    240                     Mexico   114
# Tournament  8065     13  FIFA World Cup Qualifiers  6635
# Attendance  7291   3378                      20000   177
# Stadium     7586   1384           National Stadium   116
# City        8031    797                Mexico City   102
# Country     8031    237                     Mexico   181
# AET Y-N     8065      2                         NO  7964
# PEN Y-N     8065      4                         NO  8014
# Pen (x*x)   8065     15                         NO  8021
# Notes         74     58      Result later annulled     7
# winner      8065    220                      EquaL  1712

# %%
football_data.duplicated().sum()
# Out:
# 0

# %%
football_data.isna().sum()
# Out:
# Date (timeline)       0
# Home Team             0
# Away Team             0
# Home Score            0
# Away Score            0
# Tournament            0
# Attendance          774
# Stadium             479
# City                 34
# Country              34
# AET Y-N               0
# PEN Y-N               0
# Pen (x*x)             0
# Notes              7991
# winner                0
# dtype: int64

# %%
football_data.drop(['Notes'], axis = 1 , inplace = True )

# %%
football_data.head(3)
# Out:
#   Date (timeline)      Home Team Away Team  Home Score  Away Score  \
# 0      1930-07-13         France    Mexico           4           1
# 1      1930-07-13  United States   Belgium           3           0
# 2      1930-07-14        Romania      Peru           3           1
#
#        Tournament Attendance                 Stadium        City  Country  \
# 0  FIFA World Cup       4444         Estadio Pocitos  Montevideo  Uruguay
# 1  FIFA World Cup      18346  Estadio Parque Central  Montevideo  Uruguay
# 2  FIFA World Cup       2549         Estadio Pocitos  Montevideo  Uruguay
#
#   AET Y-N PEN Y-N Pen (x*x)         winner
# 0      NO      NO        NO         France
# 1      NO      NO        NO  United States
# 2      NO      NO        NO        Romania

# %%
football_data['year'] = football_data['Date (timeline)'].dt.year
football_data['month'] = football_data['Date (timeline)'].dt.month
football_data['day'] = football_data['Date (timeline)'].dt.day
football_data['day_name'] = football_data['Date (timeline)'].dt.day_name()

# %%
football_data.head(3)
# Out:
#   Date (timeline)      Home Team Away Team  Home Score  Away Score  \
# 0      1930-07-13         France    Mexico           4           1
# 1      1930-07-13  United States   Belgium           3           0
# 2      1930-07-14        Romania      Peru           3           1
#
#        Tournament Attendance                 Stadium        City  Country  \
# 0  FIFA World Cup       4444         Estadio Pocitos  Montevideo  Uruguay
# 1  FIFA World Cup      18346  Estadio Parque Central  Montevideo  Uruguay
# 2  FIFA World Cup       2549         Estadio Pocitos  Montevideo  Uruguay
#
#   AET Y-N PEN Y-N Pen (x*x)         winner  year  month  day day_name
# 0      NO      NO        NO         France  1930      7   13   Sunday
# 1      NO      NO        NO  United States  1930      7   13   Sunday
# 2      NO      NO        NO        Romania  1930      7   14   Monday

# %%
years_lst = football_data['year'].unique()

# %%
football_data['year'].nunique()
# Out:
# 63

# %%
years_lst[0]
# Out:
# 1930

# %%
football_data.head(3)
# Out:
#   Date (timeline)      Home Team Away Team  Home Score  Away Score  \
# 0      1930-07-13         France    Mexico           4           1
# 1      1930-07-13  United States   Belgium           3           0
# 2      1930-07-14        Romania      Peru           3           1
#
#        Tournament Attendance                 Stadium        City  Country  \
# 0  FIFA World Cup       4444         Estadio Pocitos  Montevideo  Uruguay
# 1  FIFA World Cup      18346  Estadio Parque Central  Montevideo  Uruguay
# 2  FIFA World Cup       2549         Estadio Pocitos  Montevideo  Uruguay
#
#   AET Y-N PEN Y-N Pen (x*x)         winner  year  month  day day_name
# 0      NO      NO        NO         France  1930      7   13   Sunday
# 1      NO      NO        NO  United States  1930      7   13   Sunday
# 2      NO      NO        NO        Romania  1930      7   14   Monday

# %% [markdown]
# # Questions to Analyses
#
# 1- how many games did egypt plays from 1930 to 2021 ?
#
# 2- how many games did egypt win ?
#
# 3- how many games did egypt play extra time ?
#
# 4- how many games did egypt win with penalties ?
#
# 5- which stadium did egypt win on it most ?
#
# 6- did egypt win most as home or a way team ?
#
# 7- what is the greatest attendence attend for egypt matches ?
#
# 8- what is the luckiest day for egypt to win ?
#
# 9- what is the most tournament for egypt to win ?
#
# 10- did egypt win more than algeria from 1930 to 2021 ?

# %%
year_beriod = football_data[football_data['year'].between(1930 , 2021)]

# %%
year_beriod.head(3)
# Out:
#   Date (timeline)      Home Team Away Team  Home Score  Away Score  \
# 0      1930-07-13         France    Mexico           4           1
# 1      1930-07-13  United States   Belgium           3           0
# 2      1930-07-14        Romania      Peru           3           1
#
#        Tournament Attendance                 Stadium        City  Country  \
# 0  FIFA World Cup       4444         Estadio Pocitos  Montevideo  Uruguay
# 1  FIFA World Cup      18346  Estadio Parque Central  Montevideo  Uruguay
# 2  FIFA World Cup       2549         Estadio Pocitos  Montevideo  Uruguay
#
#   AET Y-N PEN Y-N Pen (x*x)         winner  year  month  day day_name
# 0      NO      NO        NO         France  1930      7   13   Sunday
# 1      NO      NO        NO  United States  1930      7   13   Sunday
# 2      NO      NO        NO        Romania  1930      7   14   Monday

# %%
egypt_plays= year_beriod[(year_beriod['Home Team'] == 'Egypt') | (year_beriod['Away Team'] == 'Egypt') ]

# %%
egypt_plays.head(5)
# Out:
#     Date (timeline)                   Home Team                   Away Team  \
# 31       1934-03-16                       Egypt  Palestine, British Mandate
# 36       1934-04-06  Palestine, British Mandate                       Egypt
# 48       1934-05-27                     Hungary                       Egypt
# 179      1953-11-13                       Egypt                       Italy
# 188      1954-01-24                       Italy                       Egypt
#
#      Home Score  Away Score                 Tournament Attendance  \
# 31            7           1  FIFA World Cup Qualifiers      13000
# 36            1           4  FIFA World Cup Qualifiers       8000
# 48            4           2             FIFA World Cup       9000
# 179           1           2  FIFA World Cup Qualifiers      22000
# 188           5           1  FIFA World Cup Qualifiers      40000
#
#                         Stadium      City                   Country AET Y-N  \
# ...

# %%
egypt_plays.count()
# Out:
# Date (timeline)    102
# Home Team          102
# Away Team          102
# Home Score         102
# Away Score         102
# Tournament         102
# Attendance          92
# Stadium            102
# City               102
# Country            102
# AET Y-N            102
# PEN Y-N            102
# Pen (x*x)          102
# winner             102
# year               102
# month              102
# day                102
# day_name           102
# dtype: int64

# %%
egypt_win_matches = egypt_plays[egypt_plays['winner']=='Egypt']

# %%
egypt_win_matches.head(5)
# Out:
#      Date (timeline)                   Home Team                   Away Team  \
# 31        1934-03-16                       Egypt  Palestine, British Mandate
# 36        1934-04-06  Palestine, British Mandate                       Egypt
# 817       1972-12-08                       Egypt                     Tunisia
# 1045      1976-10-29                       Egypt                    Ethiopia
# 1053      1976-11-14                    Ethiopia                       Egypt
#
#       Home Score  Away Score                 Tournament Attendance  \
# 31             7           1  FIFA World Cup Qualifiers      13000
# 36             1           4  FIFA World Cup Qualifiers       8000
# 817            2           1  FIFA World Cup Qualifiers      11707
# 1045           3           0  FIFA World Cup Qualifiers     120000
# 1053           1           2  FIFA World Cup Qualifiers     150000
#
#                   Stadium         City                   Country AET Y-N  \
# ...

# %%
egypt_win_matches['winner'].count()
# Out:
# 54

# %%
egypt_equal_matches = egypt_plays[egypt_plays['winner']=='EquaL']

# %%
egypt_equal_matches.head(5)
# Out:
#      Date (timeline) Home Team Away Team  Home Score  Away Score  \
# 1066      1977-02-06     Kenya     Egypt           0           0
# 1158      1977-07-31    Zambia     Egypt           0           0
# 1409      1981-05-08     Egypt   Morocco           0           0
# 1604      1984-09-30  Zimbabwe     Egypt           1           1
# 1802      1985-07-12     Egypt   Morocco           0           0
#
#                      Tournament Attendance                      Stadium  \
# 1066  FIFA World Cup Qualifiers       8337         Nairobi City Stadium
# 1158  FIFA World Cup Qualifiers     130165              7 April Stadium
# 1409  FIFA World Cup Qualifiers     100000               Nasser Stadium
# 1604  FIFA World Cup Qualifiers      40000               Rufaro Stadium
# 1802  FIFA World Cup Qualifiers        NaN  Cairo International Stadium
#
#          City   Country AET Y-N PEN Y-N Pen (x*x) winner  year  month  day  \
# ...

# %%
egypt_equal_matches['winner'].count()
# Out:
# 21

# %%
egypt_plays.head(5)
# Out:
#     Date (timeline)                   Home Team                   Away Team  \
# 31       1934-03-16                       Egypt  Palestine, British Mandate
# 36       1934-04-06  Palestine, British Mandate                       Egypt
# 48       1934-05-27                     Hungary                       Egypt
# 179      1953-11-13                       Egypt                       Italy
# 188      1954-01-24                       Italy                       Egypt
#
#      Home Score  Away Score                 Tournament Attendance  \
# 31            7           1  FIFA World Cup Qualifiers      13000
# 36            1           4  FIFA World Cup Qualifiers       8000
# 48            4           2             FIFA World Cup       9000
# 179           1           2  FIFA World Cup Qualifiers      22000
# 188           5           1  FIFA World Cup Qualifiers      40000
#
#                         Stadium      City                   Country AET Y-N  \
# ...

# %%
egypt_extra_time = egypt_plays[egypt_plays['AET Y-N'] == 'YES']

# %%
egypt_extra_time
# Out:
#      Date (timeline)   Home Team Away Team  Home Score  Away Score  \
# 1737      1985-04-21  Madagascar     Egypt           1           0
#
#                      Tournament Attendance                       Stadium  \
# 1737  FIFA World Cup Qualifiers        NaN  Mahamasina Municipal Stadium
#
#               City     Country AET Y-N PEN Y-N Pen (x*x)      winner  year  \
# 1737  Antananarivo  Madagascar     YES     YES       2*4  Madagascar  1985
#
#       month  day day_name
# 1737      4   21   Sunday

# %%
egypt_win_matches.head(5)
# Out:
#      Date (timeline)                   Home Team                   Away Team  \
# 31        1934-03-16                       Egypt  Palestine, British Mandate
# 36        1934-04-06  Palestine, British Mandate                       Egypt
# 817       1972-12-08                       Egypt                     Tunisia
# 1045      1976-10-29                       Egypt                    Ethiopia
# 1053      1976-11-14                    Ethiopia                       Egypt
#
#       Home Score  Away Score                 Tournament Attendance  \
# 31             7           1  FIFA World Cup Qualifiers      13000
# 36             1           4  FIFA World Cup Qualifiers       8000
# 817            2           1  FIFA World Cup Qualifiers      11707
# 1045           3           0  FIFA World Cup Qualifiers     120000
# 1053           1           2  FIFA World Cup Qualifiers     150000
#
#                   Stadium         City                   Country AET Y-N  \
# ...

# %%
egypt_win_matches['Stadium'].value_counts().plot(kind='bar')

# %%
egypt_win_matches['Home Team'].value_counts()
# Out:
# Egypt                         40
# Palestine, British Mandate     1
# Ethiopia                       1
# Togo                           1
# Namibia                        1
# Mauritius                      1
# Sudan                          1
# Djibouti                       1
# DR Congo                       1
# Rwanda                         1
# Zambia                         1
# Guinea                         1
# Zimbabwe                       1
# Mozambique                     1
# Congo                          1
# Name: Home Team, dtype: int64

# %%
egypt_win_matches['Away Team'].value_counts()
# Out:
# Egypt                         14
# Liberia                        3
# Zimbabwe                       3
# Algeria                        3
# Tunisia                        2
# Kenya                          2
# Ghana                          2
# Namibia                        2
# Malawi                         2
# Rwanda                         1
# DR Congo                       1
# Djibouti                       1
# Palestine, British Mandate     1
# Mozambique                     1
# Sudan                          1
# Guinea                         1
# Chad                           1
# Uganda                         1
# Benin                          1
# Mauritius                      1
# Libya                          1
# Cameroon                       1
# Senegal                        1
# Togo                           1
# Angola                         1
# Madagascar                     1
# Nigeria                        1
# Zambia                         1
# ...

# %%
egypt_plays.head(5)
# Out:
#     Date (timeline)                   Home Team                   Away Team  \
# 31       1934-03-16                       Egypt  Palestine, British Mandate
# 36       1934-04-06  Palestine, British Mandate                       Egypt
# 48       1934-05-27                     Hungary                       Egypt
# 179      1953-11-13                       Egypt                       Italy
# 188      1954-01-24                       Italy                       Egypt
#
#      Home Score  Away Score                 Tournament Attendance  \
# 31            7           1  FIFA World Cup Qualifiers      13000
# 36            1           4  FIFA World Cup Qualifiers       8000
# 48            4           2             FIFA World Cup       9000
# 179           1           2  FIFA World Cup Qualifiers      22000
# 188           5           1  FIFA World Cup Qualifiers      40000
#
#                         Stadium      City                   Country AET Y-N  \
# ...

# %%
egypt_plays['Attendance'].max()
# Out:
# 190000

# %%
egypt_plays[egypt_plays['Attendance'] == 190000]
# Out:
#      Date (timeline) Home Team Away Team  Home Score  Away Score  \
# 1192      1977-10-21     Egypt   Nigeria           3           1
#
#                      Tournament Attendance         Stadium   City Country  \
# 1192  FIFA World Cup Qualifiers     190000  Nasser Stadium  Cairo   Egypt
#
#      AET Y-N PEN Y-N Pen (x*x) winner  year  month  day day_name
# 1192      NO      NO        NO  Egypt  1977     10   21   Friday

# %%
egypt_win_matches['day_name'].value_counts().plot(kind='pie')

# %%
egypt_win_matches['Tournament'].value_counts()
# Out:
# FIFA World Cup Qualifiers                                        44
# FIFA World Cup Qualifiers / African Cup of Nations Qualifiers     9
# Friendly                                                          1
# Name: Tournament, dtype: int64

# %%
egypt_win_matches['winner'].value_counts()
# Out:
# Egypt    54
# Name: winner, dtype: int64

# %%
Algeria_win_matches = football_data[football_data['winner']=='Algeria']

# %%
Algeria_win_matches['winner'].value_counts()
# Out:
# Algeria    44
# Name: winner, dtype: int64

# %%
egypt_and_alegria_win = football_data[(football_data['winner'] == 'Egypt') | (football_data['winner'] == 'Algeria')]

# %%
egypt_and_alegria_win
# Out:
#      Date (timeline)                   Home Team                   Away Team  \
# 31        1934-03-16                       Egypt  Palestine, British Mandate
# 36        1934-04-06  Palestine, British Mandate                       Egypt
# 767       1972-03-02                     Algeria                      Guinea
# 817       1972-12-08                       Egypt                     Tunisia
# 1017      1976-04-01                     Algeria                       Libya
# ...              ...                         ...                         ...
# 7633      2016-11-13                       Egypt                       Ghana
# 7845      2017-09-05                       Egypt                      Uganda
# 7909      2017-10-08                       Egypt                       Congo
# 7948      2017-11-10                     Algeria                     Nigeria
# 8052      2021-09-30                       Egypt                     Liberia
#
# ...

# %%
egypt_and_alegria_win['winner'].value_counts()
# Out:
# Egypt      54
# Algeria    44
# Name: winner, dtype: int64

# %%
attendance_stadium = football_data[['Stadium' , 'Attendance']]

# %%
attendance_stadium['Attendance'] = pd.to_numeric(attendance_stadium['Attendance'],errors = 'coerce')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
attendance_stadium.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8065 entries, 0 to 8064
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Stadium     7586 non-null   object
#  1   Attendance  7271 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 126.1+ KB

# %%
x = attendance_stadium.groupby('Stadium')['Attendance'].mean().sort_values(ascending = False)
order = x.index

# %%
x
# Out:
# Stadium
# Estádio Dr. Magalhães Pessoa     227214.000000
# William Mkapa Stadium            142970.000000
# Nasser Stadium                   106383.666667
# Dag Hammarskjöld Stadium          95792.750000
# Stade Mohamed V                   95474.266667
#                                      ...
# Stadio del Conero                          NaN
# Stadion Ukraijna                           NaN
# Tivoli-Neu                                 NaN
# Vasil Levski National Stadium              NaN
# Xiannogtan Stadium                         NaN
# Name: Attendance, Length: 1384, dtype: float64

# %%
color = sns.color_palette()[-1]

sns.barplot(data = attendance_stadium, x = 'Stadium', y = 'Attendance', ci = None,
            order = order, color = color)
plt.xticks(rotation = 90);
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\DELL\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
egypt_win_matches
# Out:
#      Date (timeline)                   Home Team                   Away Team  \
# 31        1934-03-16                       Egypt  Palestine, British Mandate
# 36        1934-04-06  Palestine, British Mandate                       Egypt
# 817       1972-12-08                       Egypt                     Tunisia
# 1045      1976-10-29                       Egypt                    Ethiopia
# 1053      1976-11-14                    Ethiopia                       Egypt
# 1078      1977-02-27                       Egypt                       Kenya
# 1155      1977-07-15                       Egypt                      Zambia
# 1192      1977-10-21                       Egypt                     Nigeria
# 1219      1977-11-25                       Egypt                     Tunisia
# 1595      1984-08-28                       Egypt                    Zimbabwe
# 1707      1985-04-05                       Egypt                  Madagascar
# ...

# %%
pivot_table = pd.pivot_table(data = egypt_win_matches , index = 'year' , columns = 'City' , values = 'Attendance' )

# %%
pivot_table
# Out:
# City  Addis Ababa  Alexandria  Brazzaville          Cairo  Chililabombwe  \
# year
# 1934          NaN         NaN          NaN   13000.000000            NaN
# 1972          NaN         NaN          NaN   11707.000000            NaN
# 1976     150000.0         NaN          NaN  120000.000000            NaN
# 1977          NaN         NaN          NaN  145186.500000            NaN
# 1984          NaN         NaN          NaN   80000.000000            NaN
# 1985          NaN         NaN          NaN   65000.000000            NaN
# 1989          NaN         NaN          NaN   68000.000000            NaN
# 1992          NaN         NaN          NaN            NaN            NaN
# 1996          NaN         NaN          NaN   35000.000000            NaN
# 1997          NaN         NaN          NaN   35000.000000            NaN
# 2000          NaN     15000.0          NaN   40000.000000            NaN
# 2001          NaN     21000.0          NaN   60000.000000            NaN
# ...
